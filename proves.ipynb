# %%
import music21
import matplotlib.pyplot as plt
import numpy as np

# %%
s = music21.corpus.parse('bach/bwv65.2.xml')

# %%
s.analyze('key')
# Out:
# <music21.key.Key of a minor>

# %%
s.show()

# %%
e=music21.note.Note('E4')

# %%
e.pitch.frequency
# Out:
# 329.62755691286986

# %%
eb = music21.note.Note('E-4')

# %%
eb.pitch.frequency
# Out:
# 311.1269837220808

# %%
eb.pitch.accidental
# Out:
# <accidental flat>

# %%
e.pitch.accidental

# %%
eb.show('midi')
# Out:
#                 <div id='midiPlayerDiv4616'></div>
#                 <link rel="stylesheet" href="http://artusi.xyz/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': 'http://artusi.xyz/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv4616');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %%
eb.transpose('m3').show()

# %%
eb.transpose('M3').show()

# %%
def plot_freq(note):
    f = note.pitch.frequency
    t = np.linspace(0,0.02,1000)
    y = np.sin(t*f*2*np.pi)
    plt.plot(t,y)

# %%
plot_freq(eb)
